# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U codeium-jupyter
# !jupyter nbextension install --py codeium --user
# !jupyter nbextension enable --py codeium --user
# !jupyter serverextension enable --py codeium --user
# Out:
# Requirement already satisfied: pip in c:\users\hamin\appdata\roaming\python\python311\site-packages (24.0)
# Requirement already satisfied: codeium-jupyter in c:\users\hamin\appdata\roaming\python\python311\site-packages (1.1.21)
# Requirement already satisfied: aiohttp in c:\users\hamin\anaconda3\lib\site-packages (from codeium-jupyter) (3.9.3)
# Requirement already satisfied: crc32c in c:\users\hamin\appdata\roaming\python\python311\site-packages (from codeium-jupyter) (2.4)
# Requirement already satisfied: jupyter in c:\users\hamin\anaconda3\lib\site-packages (from codeium-jupyter) (1.0.0)
# Requirement already satisfied: jupyter_core in c:\users\hamin\anaconda3\lib\site-packages (from codeium-jupyter) (5.5.0)
# Requirement already satisfied: nbconvert in c:\users\hamin\anaconda3\lib\site-packages (from codeium-jupyter) (7.10.0)
# Requirement already satisfied: notebook>=4.2 in c:\users\hamin\anaconda3\lib\site-packages (from codeium-jupyter) (6.5.4)
# Requirement already satisfied: jinja2 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (3.1.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (6.3.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (24.0.1)
# Requirement already satisfied: argon2-cffi in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (21.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (5.7.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (7.4.9)
# Requirement already satisfied: ipython-genutils in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (1.6.0)
# Requirement already satisfied: ipykernel in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (6.28.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hamin\anaconda3\lib\site-packages (from notebook>=4.2->codeium-jupyter) (1.0.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter_core->codeium-jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter_core->codeium-jupyter) (305.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (0.8.0)
# Requirement already satisfied: packaging in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert->codeium-jupyter) (1.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hamin\anaconda3\lib\site-packages (from aiohttp->codeium-jupyter) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hamin\anaconda3\lib\site-packages (from aiohttp->codeium-jupyter) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hamin\anaconda3\lib\site-packages (from aiohttp->codeium-jupyter) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hamin\anaconda3\lib\site-packages (from aiohttp->codeium-jupyter) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hamin\anaconda3\lib\site-packages (from aiohttp->codeium-jupyter) (1.9.3)
# Requirement already satisfied: qtconsole in c:\users\hamin\anaconda3\lib\site-packages (from jupyter->codeium-jupyter) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\hamin\anaconda3\lib\site-packages (from jupyter->codeium-jupyter) (6.6.3)
# Requirement already satisfied: ipywidgets in c:\users\hamin\anaconda3\lib\site-packages (from jupyter->codeium-jupyter) (7.6.5)
# Requirement already satisfied: six>=1.9.0 in c:\users\hamin\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->codeium-jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\hamin\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->codeium-jupyter) (0.5.1)
# Requirement already satisfied: entrypoints in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->codeium-jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.2->codeium-jupyter) (2.8.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hamin\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (2.10.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\users\hamin\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.2.3)
# Requirement already satisfied: fastjsonschema in c:\users\hamin\anaconda3\lib\site-packages (from nbformat->notebook>=4.2->codeium-jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hamin\anaconda3\lib\site-packages (from nbformat->notebook>=4.2->codeium-jupyter) (4.19.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hamin\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.2->codeium-jupyter) (2.0.10)
# Requirement already satisfied: idna>=2.0 in c:\users\hamin\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->codeium-jupyter) (3.4)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hamin\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.2->codeium-jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hamin\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->codeium-jupyter) (2.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (8.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (0.1.6)
# Requirement already satisfied: psutil in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel->notebook>=4.2->codeium-jupyter) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hamin\anaconda3\lib\site-packages (from ipywidgets->jupyter->codeium-jupyter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from ipywidgets->jupyter->codeium-jupyter) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-console->jupyter->codeium-jupyter) (3.0.43)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\hamin\anaconda3\lib\site-packages (from qtconsole->jupyter->codeium-jupyter) (2.4.1)
# Requirement already satisfied: decorator in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->codeium-jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->codeium-jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=4.2->codeium-jupyter) (0.10.6)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.4.4)
# Requirement already satisfied: overrides in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (7.4.0)
# Requirement already satisfied: websocket-client in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.58.0)
# Requirement already satisfied: wcwidth in c:\users\hamin\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->codeium-jupyter) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hamin\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.2->codeium-jupyter) (1.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hamin\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\hamin\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.2->codeium-jupyter) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hamin\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.8.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (0.1.1)
# Requirement already satisfied: executing in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=4.2->codeium-jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (2.1)
# Requirement already satisfied: uri-template in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (24.6.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hamin\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.2->codeium-jupyter) (1.2.3)
# Installing C:\Users\hamin\AppData\Roaming\Python\Python311\site-packages\codeium\static -> codeium
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium.yaml
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_error.svg
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_inactive.svg
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_logo.svg
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_processing.svg
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\codeium_square_warning.svg
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\main.css
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\main.js
# Up to date: C:\Users\hamin\AppData\Roaming\jupyter\nbextensions\codeium\README.rst
# - Validating: ok
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable codeium --user --py
#
# Enabling notebook extension codeium/main...
#       - Validating: ok
# Enabling: codeium
# - Writing config: C:\Users\hamin\.jupyter
#     - Validating...
#       codeium  ok

# %%
import pandas as

# %%
conda config --add channels conda-forge
conda config --set channel_priority strict
conda install jupyterlab~=3.0
# Out:
#   Cell In[2], line 1
#     conda config --add channels conda-forge
#           ^
# SyntaxError: invalid syntax

# %%
pip install jupyterlab~=4.0
# Out:
# Collecting jupyterlab~=4.0
#   Using cached jupyterlab-4.2.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab~=4.0)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (3.1.3)
# Requirement already satisfied: jupyter-core in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (2.10.0)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab~=4.0)
#   Using cached jupyterlab_server-2.27.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (0.2.3)
# Requirement already satisfied: packaging in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (23.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (6.3.3)
# Requirement already satisfied: traitlets in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab~=4.0) (5.7.1)
# Requirement already satisfied: anyio in c:\users\hamin\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0) (4.2.0)
# Requirement already satisfied: certifi in c:\users\hamin\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab~=4.0)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\hamin\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0) (3.4)
# Requirement already satisfied: sniffio in c:\users\hamin\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab~=4.0) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab~=4.0)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (1.6.0)
# Requirement already satisfied: psutil in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\hamin\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab~=4.0) (24.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hamin\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab~=4.0) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-core->jupyterlab~=4.0) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-core->jupyterlab~=4.0) (305.1)
# Requirement already satisfied: argon2-cffi in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (5.9.2)
# Requirement already satisfied: overrides in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.58.0)
# Requirement already satisfied: babel>=2.10 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\hamin\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2.31.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\hamin\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2023.3.post1)
# Requirement already satisfied: decorator in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.2.0)
# Requirement already satisfied: colorama in c:\users\hamin\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (0.10.6)
# Requirement already satisfied: entrypoints in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab~=4.0) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab~=4.0) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hamin\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\hamin\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\hamin\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hamin\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hamin\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab~=4.0) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hamin\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (21.2.0)
# Requirement already satisfied: six in c:\users\hamin\anaconda3\lib\site-packages (from websocket-client->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\hamin\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hamin\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.8.3)
# Requirement already satisfied: fqdn in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hamin\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.1)
# Requirement already satisfied: uri-template in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hamin\appdata\roaming\python\python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (24.6.0)
# Requirement already satisfied: wcwidth in c:\users\hamin\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hamin\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hamin\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.5)
# Requirement already satisfied: executing in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hamin\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab~=4.0) (0.2.2)
# Requirement already satisfied: pycparser in c:\users\hamin\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hamin\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab~=4.0) (1.2.3)
# Using cached jupyterlab-4.2.1-py3-none-any.whl (11.6 MB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: h11, httpcore, httpx, jupyterlab-server, jupyterlab
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab_server 2.25.1
#     Uninstalling jupyterlab_server-2.25.1:
#       Successfully uninstalled jupyterlab_server-2.25.1
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 3.6.7
#     Uninstalling jupyterlab-3.6.7:
#       Successfully uninstalled jupyterlab-3.6.7
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jupyterlab-4.2.1 jupyterlab-server-2.27.2
# Note: you may need to restart the kernel to use updated packages.

# %%
conda config --add channels conda-forge
conda config --set channel_priority strict
conda install jupyterlab~=4.0
# Out:
#   Cell In[1], line 1
#     conda config --add channels conda-forge
#           ^
# SyntaxError: invalid syntax
